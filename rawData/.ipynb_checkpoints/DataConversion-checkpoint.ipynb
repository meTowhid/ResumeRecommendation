# %%
import pandas as pd

# %%
from os import listdir
from os.path import isfile, join

def getFilePaths(folder):
    f = [f for f in listdir(folder) if isfile(join(folder, f)) and f.endswith('.json')]
    return [folder + '/' + file for file in f]

# %%
getFilePaths(folder='json')
# Out:
# ['json/dataset_accountant.json',
#  'json/dataset_ecommers_operation_executive.json',
#  'json/dataset_it_engineer.json',
#  'json/dataset_designer.json',
#  'json/dataset_hr_executive.json',
#  'json/dataset_account_manager.json',
#  'json/dataset_ecommers_operation_executive_selected.json',
#  'json/dataset_manager.json']

# %%
filename = 'json/dataset_designer.json'
df = pd.read_json(filename)
df.head()
# Out:
#     Age   ApplicantLocation   AppliedDate         AppliedNo    ApplyID  \
# 0  28.2      Rampura, Dhaka  Jun 15, 2019   1 Time Applied   158696216
# 1  24.8  Mohammadpur, Dhaka  Jun 11, 2019  2 Times Applied   158347775
# 2  19.8      Rampura, Dhaka  Jun 15, 2019  2 Times Applied   158686626
# 3  30.8       Mirpur, Dhaka  Jun 19, 2019   1 Time Applied   159068520
# 4  27.6  Mohammadpur, Dhaka  Jun 15, 2019   1 Time Applied   158650232
#
#   AssesmntRank  AssessmentCat  Cetificate      ChkVal Comment_Date  ...  \
# 0                           0           0  1586962160               ...
# 1                           0           0  1583477750               ...
# 2                           0           0  1586866260               ...
# 3                           0           0  1590685200               ...
# 4                           0           0  1586502320               ...
#
#                        Name  \
# 0           Md.Alahan Uddin
# 1         Asif Arefin Bonny
# 2            Deloar Hossain
# 3  Mamun or Rasheed mohosin
# 4         myen Uddin shohag
#
#                                                Photo  SLNo  Salary SchduleNo  \
# 0  https://my.bdjobs.com/photos/1025001-1050000/4...     1  45,000         0
# 1  https://my.bdjobs.com/photos/2975001-3000000/1...     2  30,000         0
# 2  https://my.bdjobs.com/photos/2750001-2775000/1...     3  11,500         0
# 3  https://my.bdjobs.com/photos/525001-550000/225...     4  25,000         0
# 4  https://my.bdjobs.com/photos/1750001-1775000/7...     5  25,000         0
#
#   SchduleRejected Status  Total_Comment  \
# 0               0      0              0
# 1               0      0              0
# 2               0      0              0
# 3               0      0              0
# 4               0      0              0
#
#                                           University  ViewStatus
# 0                               Jagannath University        True
# 1                           Jahangirnagar University       False
# 2  Shaheed AHM Kamaruzzaman Government Degree Col...        True
# 3                   Jagannath University, Bangladesh       False
# 4                            Feni Computer Institute       False
#
# [5 rows x 35 columns]

# %%
def getDataFrameFromFile(filename):
    df = pd.read_html(filename)
    df = df[1]
    df.columns = df.iloc[0]
    df.drop(df.index[0], inplace=True)
    return df

def processDataFrame(df):
    df.rename(columns={'Name': 'raw', 'Career Summary': 'last_company', 'Experience & Application Status': 'experience'}, inplace=True)

#     df['raw'][0].split('\n')

    d = df.raw.str.split('\n')
    df['name'] = d.str.get(0)
    df['age'] = d.str.get(1).replace('Age:','')
    df['versity'] = d.str.get(3)
    df['subject'] = d.str.get(4)
    df['matching_rate'] = d.str.get(5) 
    # df['phone'] = d.str.get(6) 

    d = df.experience.str.split('\n')
    df['salary'] = d.str.get(1)
    df['experience'] = d.str.get(0)
    df.head()


    headers = ['name', 
    #              'phone', 
                'age', 
                'versity',
                'subject',
                'last_company',
                'experience',
                'salary', 
                'matching_rate']
    df.drop(columns='raw', inplace=True)
    df = df.reindex(headers, axis=1)

    df.age = df.age.str.extract('(\d+\.?\d*)',expand=True).astype(float)
    df.last_company = df.last_company.str.split('\n').str.get(0)
    df.experience = df.experience.str.extract('(\d+)',expand=True).astype(int)
    df.salary = df.salary.str.extract('(\d+\,?\d*)',expand=True).get(0).str.replace(',','').astype(int)
    df.matching_rate = df.matching_rate.str.extract('(\d+)',expand=True).astype(int)
    
    return df

# %%
df = getDataFrameFromFile('am/Accounts+Manager_01.xls')
df.head()
# Out:
# 0 SL Photo                                               Name  \
# 1  1   NaN  MD. AZIZUL HAQUE (AZIZ)Age: 40.2Badda, DhakaNa...
# 2  2   NaN  MD.REMAN BHUIYANAge: 34.4Badda, DhakaNational ...
# 3  3   NaN  Md. Mamunur RashidAge: 39.9Badda, DhakaNationa...
# 4  4   NaN  Adnan EnamAge: 36.8Badda, DhakaStamford Univer...
# 5  5   NaN  MD ABDUL HALIMAge: 44.0Gulshan, DhakaIBAIS Uni...
#
# 0                                     Career Summary  \
# 1  Dhaka Cotton, Tafrid Cotton Mills & Unilon Tex...
# 2  REDOX CHEMICALS INDUSTRIES LIMITED (S&D CHEMIC...
# 3  ATS Group(Spinning,Sweater Manufacturing, trad...
# 4  Standard GroupSenior Financial Accounts Office...
# 5  Provita GroupManager (account & Finance) (2+ y...
#
# 0                    Experience & Application Status    Applied on
# 1  Total Experience: 13+ YearsSalary: 40,0001 Tim...  Dec 19, 2018
# 2  Total Experience: 8+ YearsSalary: 40,0001 Time...  Dec 19, 2018
# 3  Total Experience: 13+ YearsSalary: 40,0001 Tim...  Dec 20, 2018
# 4  Total Experience: 10+ YearsSalary: 50,0001 Tim...  Dec 20, 2018
# 5  Total Experience: 13+ YearsSalary: 60,0001 Tim...  Dec 20, 2018

# %%
# df.last_company.get(1)
processDataFrame(df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-300e4ad38271> in <module>
#       1 # df.last_company.get(1)
# ----> 2 processDataFrame(df)
#
# <ipython-input-46-cd2908df42a0> in processDataFrame(df)
#      11 #     df['raw'][0].split('\n')
#      12
# ---> 13     d = df.raw.str.split('\n')
#      14     df['name'] = d.str.get(0)
#      15     df['age'] = d.str.get(1).replace('Age:','')
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'raw'

# %%
df.rename(columns={'Name': 'raw', 'Career Summary': 'last_company', 'Experience & Application Status': 'experience', 'Unnamed: 3': 'salary'}, inplace=True)
df.head()
# Out:
#                                                  raw  \
# 0  Istiaque Ahmed\nAge: 31.7\nDakshin Khan, Dhaka...
# 1  Sayed Sudip Ahmed\nAge: 35.6\nDhanmondi, Dhaka...
# 2  Md.Nazrul Islam\nAge: 36.5\nDemra, Dhaka\nJaga...
# 3  Afzal Hossain Riaz\nAge: 30.8\nPallabi, Dhaka\...
# 4  Md.Mafijul Islam\nAge: 54.7\nHazaribagh, Dhaka...
#
#                                         last_company  \
# 0  ACI Godrej Agrovet Private Limited\nSenior Exe...
# 1  aaa collections\nSr. Executive, HR & Admin (3+...
# 2  Global Heavy Chemical ltd (Opsonin Group)\nSr....
# 3  Apple Tree International School\nClass Teacher...
# 4  Institute of Water Modelling (IWM)\nSecretary ...
#
#                     experience          salary
# 0   Total Experience: 8+ Years  Salary: 65,000
# 1   Total Experience: 7+ Years  Salary: 25,000
# 2  Total Experience: 10+ Years  Salary: 28,000
# 3   Total Experience: 6+ Years  Salary: 40,000
# 4  Total Experience: 29+ Years  Salary: 35,000

# %%
df['raw'][0].split('\n')
# Out:
# ['Istiaque Ahmed',
#  'Age: 31.7',
#  'Dakshin Khan, Dhaka',
#  'IBA, Jahangirnagar University',
#  'MBA',
#  'Job Matching: 80%',
#  '01774934288, 01533894978']

# %%
d = df.raw.str.split('\n')
df['name'] = d.str.get(0)
df['age'] = d.str.get(1).replace('Age:','')
df['versity'] = d.str.get(3)
df['subject'] = d.str.get(4)
df['matching_rate'] = d.str.get(5) 
# df['phone'] = d.str.get(6) 

d = df.experience.str.split('\n')
df['salary'] = d.str.get(1)
df['experience'] = d.str.get(0)
df.head()
# Out:
#                                                  raw  \
# 0  Istiaque Ahmed\nAge: 31.7\nDakshin Khan, Dhaka...
# 1  Sayed Sudip Ahmed\nAge: 35.6\nDhanmondi, Dhaka...
# 2  Md.Nazrul Islam\nAge: 36.5\nDemra, Dhaka\nJaga...
# 3  Afzal Hossain Riaz\nAge: 30.8\nPallabi, Dhaka\...
# 4  Md.Mafijul Islam\nAge: 54.7\nHazaribagh, Dhaka...
#
#                                         last_company  \
# 0  ACI Godrej Agrovet Private Limited\nSenior Exe...
# 1  aaa collections\nSr. Executive, HR & Admin (3+...
# 2  Global Heavy Chemical ltd (Opsonin Group)\nSr....
# 3  Apple Tree International School\nClass Teacher...
# 4  Institute of Water Modelling (IWM)\nSecretary ...
#
#                     experience          salary                name        age  \
# 0   Total Experience: 8+ Years  Salary: 65,000      Istiaque Ahmed  Age: 31.7
# 1   Total Experience: 7+ Years  Salary: 25,000   Sayed Sudip Ahmed  Age: 35.6
# 2  Total Experience: 10+ Years  Salary: 28,000     Md.Nazrul Islam  Age: 36.5
# 3   Total Experience: 6+ Years  Salary: 40,000  Afzal Hossain Riaz  Age: 30.8
# 4  Total Experience: 29+ Years  Salary: 35,000    Md.Mafijul Islam  Age: 54.7
#
#                          versity  \
# 0  IBA, Jahangirnagar University
# 1            University of Dhaka
# 2           Jagannath University
# 3         North South University
# 4           Jagannath University
#
#                                             subject      matching_rate
# 0                                               MBA  Job Matching: 80%
# 1  Master of Professional Human Resource Management  Job Matching: 80%
# 2                                             M.Com  Job Matching: 80%
# 3                                               MBA  Job Matching: 80%
# 4                                  Bachelor of Arts  Job Matching: 80%

# %%
headers = ['name', 
#              'phone', 
             'age', 
             'versity',
             'subject',
             'last_company',
             'experience',
             'salary', 
             'matching_rate']
df.drop(columns='raw', inplace=True)
df = df.reindex(headers, axis=1)
df.head()
# Out:
#                  name        age                        versity  \
# 0      Istiaque Ahmed  Age: 31.7  IBA, Jahangirnagar University
# 1   Sayed Sudip Ahmed  Age: 35.6            University of Dhaka
# 2     Md.Nazrul Islam  Age: 36.5           Jagannath University
# 3  Afzal Hossain Riaz  Age: 30.8         North South University
# 4    Md.Mafijul Islam  Age: 54.7           Jagannath University
#
#                                             subject  \
# 0                                               MBA
# 1  Master of Professional Human Resource Management
# 2                                             M.Com
# 3                                               MBA
# 4                                  Bachelor of Arts
#
#                                         last_company  \
# 0  ACI Godrej Agrovet Private Limited\nSenior Exe...
# 1  aaa collections\nSr. Executive, HR & Admin (3+...
# 2  Global Heavy Chemical ltd (Opsonin Group)\nSr....
# 3  Apple Tree International School\nClass Teacher...
# 4  Institute of Water Modelling (IWM)\nSecretary ...
#
#                     experience          salary      matching_rate
# 0   Total Experience: 8+ Years  Salary: 65,000  Job Matching: 80%
# 1   Total Experience: 7+ Years  Salary: 25,000  Job Matching: 80%
# 2  Total Experience: 10+ Years  Salary: 28,000  Job Matching: 80%
# 3   Total Experience: 6+ Years  Salary: 40,000  Job Matching: 80%
# 4  Total Experience: 29+ Years  Salary: 35,000  Job Matching: 80%

# %%
df.age = df.age.str.extract('(\d+\.?\d*)',expand=True).astype(float)
df.last_company = df.last_company.str.split('\n').str.get(0)
df.experience = df.experience.str.extract('(\d+)',expand=True).astype(int)
df.salary = df.salary.str.extract('(\d+\,?\d*)',expand=True).get(0).str.replace(',','').astype(int)
df.matching_rate = df.matching_rate.str.extract('(\d+)',expand=True).astype(int)
df.head()
# Out:
#                  name   age                        versity  \
# 0      Istiaque Ahmed  31.7  IBA, Jahangirnagar University
# 1   Sayed Sudip Ahmed  35.6            University of Dhaka
# 2     Md.Nazrul Islam  36.5           Jagannath University
# 3  Afzal Hossain Riaz  30.8         North South University
# 4    Md.Mafijul Islam  54.7           Jagannath University
#
#                                             subject  \
# 0                                               MBA
# 1  Master of Professional Human Resource Management
# 2                                             M.Com
# 3                                               MBA
# 4                                  Bachelor of Arts
#
#                                 last_company  experience  salary  \
# 0         ACI Godrej Agrovet Private Limited           8   65000
# 1                            aaa collections           7   25000
# 2  Global Heavy Chemical ltd (Opsonin Group)          10   28000
# 3            Apple Tree International School           6   40000
# 4         Institute of Water Modelling (IWM)          29   35000
#
#    matching_rate
# 0             80
# 1             80
# 2             80
# 3             80
# 4             80

# %%
df.dtypes
# Out:
# name              object
# age              float64
# versity           object
# subject           object
# last_company      object
# experience         int64
# salary             int64
# matching_rate      int64
# dtype: object

# %%
df.to_excel(filename.replace('.xlsx','_out.xlsx'), index=False, columns=headers)
